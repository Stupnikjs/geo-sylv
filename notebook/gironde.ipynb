# %%
import geopandas as gpd
import sys
from pathlib import Path

# Remonte d'un cran par rapport au dossier courant (notebooks/ -> mon_projet/) et pointe vers src/
src_path = Path("..").resolve() / "src"

if str(src_path) not in sys.path:
    sys.path.append(str(src_path))

# Désormais, vous pouvez importer vos modules directement :
from main import run, run_by_year
from ingest.raster import read_clipped_bands
from store import load, save

# %%
df = gpd.read_file("../data/projects/gironde/gironde.geojson")
df["area"] = df.to_crs(epsg=2154).area / 10_000
df = df.sort_values("area")
bigest = df.iloc[[-1]].to_file("../data/projects/gironde/biggest.geojson", driver="GeoJSON")

# %%
df = run(zone_name="gironde",path_or_df=bigest, end_date="2025-12-31",  start_date="2019-01-01", index="ndvi", output_dir="../data/projects/gironde")
# Out:
# Zone : gironde
# Bbox : [-1.043035832933334, 45.42774328151462, -1.039934444984568, 45.428943408408465]
# Aire de la zone : 1.4 ha
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = run(zone_name="gironde",path_or_df=bigest, end_date="2025-12-31",  start_date="2019-01-01", index="ndvi", output_dir="../data/projects/gironde")
#
# File ~/geo-sylv/src/main.py:140, in run(zone_name, path_or_df, start_date, end_date, index, output_dir)
#     136 catalog = Client.open("https://catalogue.dataspace.copernicus.eu/stac")
#     139 # liste d'objets pystac.Item — chacun représentant une scène, avec ses métadonnées et ses liens vers les fichiers image
# --> 140 items = search_with_retry(
#     141     catalog,
#     142     collections=["sentinel-2-l2a"],
#     143     bbox=bbox,
#     144     datetime=f"{start_date}/{end_date}",
#     145 )
# ...
